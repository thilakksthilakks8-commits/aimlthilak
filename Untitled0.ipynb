# %%
print("Hello world")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1145957204.py in <cell line: 0>()
# ----> 1 Print("Hello world")
#
# NameError: name 'Print' is not defined
