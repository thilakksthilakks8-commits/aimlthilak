# %%
def say_hello():
    print("Hello,welcome to python ")

# %%
def say_hello():
      print("Hello,welcome to python ")

# %%
def say_thilak():
      print("my name is thilak")

# %%
my_name_is()
# Out:
#   File "/tmp/ipython-input-3382497376.py", line 1
#     my Name is()
#        ^
# SyntaxError: invalid syntax

# %%
def greet(name):
   print("hello",name)
   greet("thilak")

# %%
def greet(name):
   print("hello goodmorning",name)
greet("thilak")
# Out:
# hello goodmorning thilak

# %%
def ( name):
   print("Hi dude how r u",name)
  greet ("Honey")
# Out:
#   File "<tokenize>", line 3
#     greet ("Honey")
#     ^
# IndentationError: unindent does not match any outer indentation level
